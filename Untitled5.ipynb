# %% [markdown]
# <a href="https://colab.research.google.com/github/Jeevalakshmi-S/micro-it/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# 1️⃣ STEP: Generate synthetic dataset
np.random.seed(42)
num_students = 300
data = {
    'Department': np.random.choice(['CSE', 'ECE', 'EEE', 'IT', 'AIDS'], num_students),
    'GPA': np.round(np.random.uniform(6.0, 10.0, num_students), 2),
    'Completed_Projects': np.random.randint(0, 6, num_students),
    'Workshops_Attended': np.random.randint(0, 5, num_students),
    'Internship_Hours': np.random.randint(10, 200, num_students),
    'Hackathons_Participated': np.random.randint(0, 4, num_students),
    'Success': np.random.choice([0, 1], num_students, p=[0.4, 0.6])  # 1 = Success, 0 = Not
}

df = pd.DataFrame(data)

# 2️⃣ STEP: Data Preprocessing
# Encode 'Department'
le = LabelEncoder()
df['Department'] = le.fit_transform(df['Department'])

# Features and target
X = df.drop('Success', axis=1)
y = df['Success']

# Normalize
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 3️⃣ STEP: Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# 4️⃣ STEP: Train Models
models = {
    "Logistic Regression": LogisticRegression(),
    "Random Forest": RandomForestClassifier(n_estimators=100),
    "Support Vector Machine": SVC(kernel='rbf')
}

# 5️⃣ STEP: Evaluate Models
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    print(f"\n🔍 Model: {name}")
    print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
    print("Classification Report:\n", classification_report(y_test, y_pred))

# 6️⃣ STEP: Plot Feature Importance (for Random Forest)
importances = models['Random Forest'].feature_importances_
features = X.columns

plt.figure(figsize=(8,6))
sns.barplot(x=importances, y=features, palette='coolwarm')
plt.title("📊 Feature Importance - Random Forest")
plt.xlabel("Importance Score")
plt.tight_layout()
plt.show()
# Out:
# 🔍 Model: Logistic Regression
# Confusion Matrix:
#  [[ 0 22]
#  [ 3 35]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        22
#            1       0.61      0.92      0.74        38
#
#     accuracy                           0.58        60
#    macro avg       0.31      0.46      0.37        60
# weighted avg       0.39      0.58      0.47        60
#
#
# 🔍 Model: Random Forest
# Confusion Matrix:
#  [[ 4 18]
#  [11 27]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.27      0.18      0.22        22
#            1       0.60      0.71      0.65        38
#
#     accuracy                           0.52        60
#    macro avg       0.43      0.45      0.43        60
# weighted avg       0.48      0.52      0.49        60
#
#
# 🔍 Model: Support Vector Machine
# Confusion Matrix:
#  [[ 3 19]
#  [13 25]]
# Classification Report:
# ...
